# %% [markdown]
# ### Weather API Request and Weather Dataset Creation

# %%
# Dependencies
import datetime
import requests
import pandas as pd
from config import api_key

# %%
# Establish base URL 
city = "Washington DC"
base_url = "https://api.weatherapi.com/v1/history.json?key=" + api_key + "&q=" + city + "&dt="

# %%
# Create list of 365 dates in Weather API format.
date = datetime.datetime.strptime("2022-02-19", "%Y-%m-%d")
K=364
date_generated = pd.date_range(date, periods=K)
date_list = date_generated.astype(dtype=str)
date_list

print(date_list)
# Out:
# Index(['2022-02-19', '2022-02-20', '2022-02-21', '2022-02-22', '2022-02-23',
#        '2022-02-24', '2022-02-25', '2022-02-26', '2022-02-27', '2022-02-28',
#        ...
#        '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-11', '2023-02-12',
#        '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17'],
#       dtype='object', length=364)

# %%
# Define an empty list to store the weather data
dc_weather = []
dc_weather_hourly = []

# Create for loop to gather API data and append daily weather to dc_weather
# and daily and hourly weather to dc_weather_hourly list
for day in date_list:
    url = base_url + day
    response = requests.get(url).json()

    date = response['forecast']['forecastday'][0]['date']
    maxtemp_f = response['forecast']['forecastday'][0]['day']['maxtemp_f']
    mintemp_f = response['forecast']['forecastday'][0]['day']['mintemp_f']
    avgtemp_f = response['forecast']['forecastday'][0]['day']['avgtemp_f']
    totalprecip_in = response['forecast']['forecastday'][0]['day']['totalprecip_in']
    day_condition = response['forecast']['forecastday'][0]['day']['condition']['text']
    temp_f_0 = response['forecast']['forecastday'][0]['hour'][0]['temp_f']
    condition_0 = response['forecast']['forecastday'][0]['hour'][0]['condition']['text']
    precip_in_0 = response['forecast']['forecastday'][0]['hour'][0]['precip_in']
    temp_f_1 = response['forecast']['forecastday'][0]['hour'][1]['temp_f']
    condition_1 = response['forecast']['forecastday'][0]['hour'][1]['condition']['text']
    precip_in_1 = response['forecast']['forecastday'][0]['hour'][1]['precip_in']
    temp_f_2 = response['forecast']['forecastday'][0]['hour'][2]['temp_f']
    condition_2 = response['forecast']['forecastday'][0]['hour'][2]['condition']['text']
    precip_in_2 = response['forecast']['forecastday'][0]['hour'][2]['precip_in']
    temp_f_3 = response['forecast']['forecastday'][0]['hour'][3]['temp_f']
    condition_3 = response['forecast']['forecastday'][0]['hour'][3]['condition']['text']
    precip_in_3 = response['forecast']['forecastday'][0]['hour'][3]['precip_in']
    temp_f_4 = response['forecast']['forecastday'][0]['hour'][4]['temp_f']
    condition_4 = response['forecast']['forecastday'][0]['hour'][4]['condition']['text']
    precip_in_4 = response['forecast']['forecastday'][0]['hour'][4]['precip_in']
    temp_f_5 = response['forecast']['forecastday'][0]['hour'][5]['temp_f']
    condition_5 = response['forecast']['forecastday'][0]['hour'][5]['condition']['text']
    precip_in_5 = response['forecast']['forecastday'][0]['hour'][5]['precip_in']
    temp_f_6 = response['forecast']['forecastday'][0]['hour'][6]['temp_f']
    condition_6 = response['forecast']['forecastday'][0]['hour'][6]['condition']['text']
    precip_in_6 = response['forecast']['forecastday'][0]['hour'][6]['precip_in']
    temp_f_7 = response['forecast']['forecastday'][0]['hour'][7]['temp_f']
    condition_7 = response['forecast']['forecastday'][0]['hour'][7]['condition']['text']
    precip_in_7 = response['forecast']['forecastday'][0]['hour'][7]['precip_in']
    temp_f_8 = response['forecast']['forecastday'][0]['hour'][8]['temp_f']
    condition_8 = response['forecast']['forecastday'][0]['hour'][8]['condition']['text']
    precip_in_8 = response['forecast']['forecastday'][0]['hour'][8]['precip_in']
    temp_f_9 = response['forecast']['forecastday'][0]['hour'][9]['temp_f']
    condition_9 = response['forecast']['forecastday'][0]['hour'][9]['condition']['text']
    precip_in_9 = response['forecast']['forecastday'][0]['hour'][9]['precip_in']
    temp_f_10 = response['forecast']['forecastday'][0]['hour'][10]['temp_f']
    condition_10 = response['forecast']['forecastday'][0]['hour'][10]['condition']['text']
    precip_in_10 = response['forecast']['forecastday'][0]['hour'][10]['precip_in']
    temp_f_11 = response['forecast']['forecastday'][0]['hour'][11]['temp_f']
    condition_11 = response['forecast']['forecastday'][0]['hour'][11]['condition']['text']
    precip_in_11 = response['forecast']['forecastday'][0]['hour'][11]['precip_in']
    temp_f_12 = response['forecast']['forecastday'][0]['hour'][12]['temp_f']
    condition_12 = response['forecast']['forecastday'][0]['hour'][12]['condition']['text']
    precip_in_12 = response['forecast']['forecastday'][0]['hour'][12]['precip_in']
    temp_f_13 = response['forecast']['forecastday'][0]['hour'][13]['temp_f']
    condition_13 = response['forecast']['forecastday'][0]['hour'][13]['condition']['text']
    precip_in_13 = response['forecast']['forecastday'][0]['hour'][13]['precip_in']
    temp_f_14 = response['forecast']['forecastday'][0]['hour'][14]['temp_f']
    condition_14 = response['forecast']['forecastday'][0]['hour'][14]['condition']['text']
    precip_in_14 = response['forecast']['forecastday'][0]['hour'][14]['precip_in']
    temp_f_15 = response['forecast']['forecastday'][0]['hour'][15]['temp_f']
    condition_15 = response['forecast']['forecastday'][0]['hour'][15]['condition']['text']
    precip_in_15 = response['forecast']['forecastday'][0]['hour'][15]['precip_in']
    temp_f_16 = response['forecast']['forecastday'][0]['hour'][16]['temp_f']
    condition_16 = response['forecast']['forecastday'][0]['hour'][16]['condition']['text']
    precip_in_16 = response['forecast']['forecastday'][0]['hour'][16]['precip_in']
    temp_f_17 = response['forecast']['forecastday'][0]['hour'][17]['temp_f']
    condition_17 = response['forecast']['forecastday'][0]['hour'][17]['condition']['text']
    precip_in_17 = response['forecast']['forecastday'][0]['hour'][17]['precip_in']
    temp_f_18 = response['forecast']['forecastday'][0]['hour'][18]['temp_f']
    condition_18 = response['forecast']['forecastday'][0]['hour'][18]['condition']['text']
    precip_in_18 = response['forecast']['forecastday'][0]['hour'][18]['precip_in']
    temp_f_19 = response['forecast']['forecastday'][0]['hour'][19]['temp_f']
    condition_19 = response['forecast']['forecastday'][0]['hour'][19]['condition']['text']
    precip_in_19 = response['forecast']['forecastday'][0]['hour'][19]['precip_in']
    temp_f_20 = response['forecast']['forecastday'][0]['hour'][20]['temp_f']
    condition_20 = response['forecast']['forecastday'][0]['hour'][20]['condition']['text']
    precip_in_20 = response['forecast']['forecastday'][0]['hour'][20]['precip_in']
    temp_f_21 = response['forecast']['forecastday'][0]['hour'][21]['temp_f']
    condition_21 = response['forecast']['forecastday'][0]['hour'][21]['condition']['text']
    precip_in_21 = response['forecast']['forecastday'][0]['hour'][21]['precip_in']
    temp_f_22 = response['forecast']['forecastday'][0]['hour'][22]['temp_f']
    condition_22 = response['forecast']['forecastday'][0]['hour'][22]['condition']['text']
    precip_in_22 = response['forecast']['forecastday'][0]['hour'][22]['precip_in']
    temp_f_23 = response['forecast']['forecastday'][0]['hour'][23]['temp_f']
    condition_23 = response['forecast']['forecastday'][0]['hour'][23]['condition']['text']
    precip_in_23 = response['forecast']['forecastday'][0]['hour'][23]['precip_in']

    # Daily
    dc_weather.append({"Date": date, "Max Temp (f)": maxtemp_f, "Min Temp (f)": mintemp_f,
                       "Avg Temp (f)": avgtemp_f, "Total Precipitation (in)": totalprecip_in,
                       "Day Condition": day_condition})

    # 12:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "12:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_0, "Hour Condition": condition_0,
                            "Hour Precipitation (in)": precip_in_0})
    
    # 1:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "1:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_1, "Hour Condition": condition_1,
                            "Hour Precipitation (in)": precip_in_1})

    # 2:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "2:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_2, "Hour Condition": condition_2,
                            "Hour Precipitation (in)": precip_in_2})

    # 3:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "3:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_3, "Hour Condition": condition_3,
                            "Hour Precipitation (in)": precip_in_3})

    # 4:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "4:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_4, "Hour Condition": condition_4,
                            "Hour Precipitation (in)": precip_in_4})
    
    # 5:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "5:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_5, "Hour Condition": condition_5,
                            "Hour Precipitation (in)": precip_in_5})

    # 6:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "6:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_6, "Hour Condition": condition_6,
                            "Hour Precipitation (in)": precip_in_6})
    
    # 7:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "7:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_7, "Hour Condition": condition_7,
                            "Hour Precipitation (in)": precip_in_7})
    
    # 8:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "8:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_8, "Hour Condition": condition_8,
                            "Hour Precipitation (in)": precip_in_8})
    
    # 9:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "9:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_9, "Hour Condition": condition_9,
                            "Hour Precipitation (in)": precip_in_9})
    
    # 10:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "10:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_10, "Hour Condition": condition_10,
                            "Hour Precipitation (in)": precip_in_10})

    # 11:00AM
    dc_weather_hourly.append({"Date": date, "Hour": "11:00AM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_11, "Hour Condition": condition_11,
                            "Hour Precipitation (in)": precip_in_11})

    # 12:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "12:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_12, "Hour Condition": condition_12,
                            "Hour Precipitation (in)": precip_in_12})
    
    # 1:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "1:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_13, "Hour Condition": condition_13,
                            "Hour Precipitation (in)": precip_in_13})

    # 2:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "2:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_14, "Hour Condition": condition_14,
                            "Hour Precipitation (in)": precip_in_14})

    # 3:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "3:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_15, "Hour Condition": condition_15,
                            "Hour Precipitation (in)": precip_in_15})

    # 4:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "4:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_16, "Hour Condition": condition_16,
                            "Hour Precipitation (in)": precip_in_16})

    # 5:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "5:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_17, "Hour Condition": condition_17,
                            "Hour Precipitation (in)": precip_in_17})

    # 6:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "6:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_18, "Hour Condition": condition_18,
                            "Hour Precipitation (in)": precip_in_18})

    # 7:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "7:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_19, "Hour Condition": condition_19,
                            "Hour Precipitation (in)": precip_in_19})

    # 8:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "8:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_20, "Hour Condition": condition_20,
                            "Hour Precipitation (in)": precip_in_20})

    # 9:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "9:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_21, "Hour Condition": condition_21,
                            "Hour Precipitation (in)": precip_in_21})
    
    # 10:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "10:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_22, "Hour Condition": condition_22,
                            "Hour Precipitation (in)": precip_in_22})

    # 11:00PM
    dc_weather_hourly.append({"Date": date, "Hour": "11:00PM", "Max Temp (f)": maxtemp_f,
                            "Min Temp (f)": mintemp_f, "Avg Temp (f)": avgtemp_f,
                            "Total Precipitation (in)": totalprecip_in, "Day Condition": day_condition,
                            "Hour Temp (f)": temp_f_23, "Hour Condition": condition_23,
                            "Hour Precipitation (in)": precip_in_23})

# Create Pandas DataFrames from dc_weather and dc_weather_hourly lists.
dc_weather_df = pd.DataFrame(dc_weather)
dc_weather_hourly_df = pd.DataFrame(dc_weather_hourly)

# %%
# Preview dc_weather DataFrame
dc_weather_df.head()

# %%
# Preview dc_weather_hourly DataFrame
dc_weather_hourly_df.head()

# %%
# Save DataFrames to .csv
dc_weather_df.to_csv("Resources/dc_weather.csv", index_label="ID")
dc_weather_hourly_df.to_csv("Resources/dc_weather_hourly.csv", index_label="ID")

# %%
# Open and preview dc_weather.csv file
file = "Resources/dc_weather.csv"
weather_df = pd.read_csv(file)
weather_df.head()
# Out:
#    ID        Date     Hour  Max Temp (f)  Min Temp (f)  Avg Temp (f)  \
# 0   0  2022-02-19  12:00AM          49.3          30.4          40.5
# 1   1  2022-02-19   1:00AM          49.3          30.4          40.5
# 2   2  2022-02-19   2:00AM          49.3          30.4          40.5
# 3   3  2022-02-19   3:00AM          49.3          30.4          40.5
# 4   4  2022-02-19   4:00AM          49.3          30.4          40.5
#
#    Total Precipitation (in) Day Condition  Hour Temp (f) Hour Condition  \
# 0                       0.0         Sunny           34.0          Clear
# 1                       0.0         Sunny           33.4          Clear
# 2                       0.0         Sunny           32.9          Clear
# 3                       0.0         Sunny           32.4          Clear
# 4                       0.0         Sunny           32.0          Clear
#
#    Hour Precipitation (in)
# 0                      0.0
# 1                      0.0
# 2                      0.0
# ...

# %%
# Open and preview dc_weather_hourly.csv file
hour_file = "Resources/dc_weather_hourly.csv"
dc_weather_hourly_df = pd.read_csv(hour_file)
dc_weather_hourly_df.head()

# %% [markdown]
# ### Crime Data Cleaning

# %%
# Open crime dataset, convert to Pandas DataFrame, and preview data
crime_file = "Resources/dc_crimes_raw_data.csv"
crime_df = pd.read_csv(crime_file)
crime_df.head()
# Out:
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT offensegroup  LONGITUDE  \
# 0           cluster 11        1100.0      violent -77.080303
# 1            cluster 7        5003.0     property -77.031960
# 2           cluster 25       10601.0     property -77.005892
# 3           cluster 39        9803.0      violent -77.004837
# 4            cluster 6        5303.0     property -77.038498
#
#                  END_DATE         offense-text  DISTRICT    YBLOCK     SHIFT  \
# 0                     NaN              robbery       2.0  142375.0   evening
# 1  3/21/2022, 10:35:00 PM  motor vehicle theft       3.0  137798.0  midnight
# 2   3/26/2022, 7:00:00 PM         theft f/auto       5.0  137708.0   evening
# 3   3/7/2022, 11:22:00 PM              robbery       7.0  129549.0  midnight
# 4  3/26/2022, 10:08:00 PM          theft/other       2.0  138099.0   evening
#
#    WARD  ...                                     BLOCK  \
# 0   3.0  ...  4530 - 4599 block of wisconsin avenue nw
# ...

# %%
# Identify all columns
crime_df.columns
# Out:
# Index(['NEIGHBORHOOD_CLUSTER', 'CENSUS_TRACT', 'offensegroup', 'LONGITUDE',
#        'END_DATE', 'offense-text', 'DISTRICT', 'YBLOCK', 'SHIFT', 'WARD',
#        'YEAR', 'offensekey', 'BID', 'sector', 'PSA', 'ucr-rank', 'BLOCK_GROUP',
#        'VOTING_PRECINCT', 'XBLOCK', 'BLOCK', 'START_DATE', 'CCN', 'OFFENSE',
#        'OCTO_RECORD_ID', 'ANC', 'REPORT_DAT', 'METHOD', 'location',
#        'LATITUDE'],
#       dtype='object')

# %%
# Remove columns that are not necessary for this analysis.
crime_df = crime_df[['START_DATE', 'offensegroup', 'OFFENSE']]
crime_df.head()
# Out:
#                START_DATE offensegroup              OFFENSE
# 0    3/7/2022, 6:14:00 PM      violent              robbery
# 1  3/20/2022, 10:27:00 PM     property  motor vehicle theft
# 2   3/26/2022, 6:33:00 PM     property         theft f/auto
# 3    3/7/2022, 9:31:00 PM      violent              robbery
# 4   3/26/2022, 9:46:00 PM     property          theft/other

# %%
# Split date and time into two columns
crime_df[['Start Date', 'Start Time']] = crime_df['START_DATE'].str.split(', ', expand=True)
# Drop original column and reorganize
crime_df = crime_df[['Start Date', 'Start Time', 'offensegroup', 'OFFENSE']]
crime_df.head()
# Out:
#   Start Date   Start Time offensegroup              OFFENSE
# 0   3/7/2022   6:14:00 PM      violent              robbery
# 1  3/20/2022  10:27:00 PM     property  motor vehicle theft
# 2  3/26/2022   6:33:00 PM     property         theft f/auto
# 3   3/7/2022   9:31:00 PM      violent              robbery
# 4  3/26/2022   9:46:00 PM     property          theft/other

# %%
# To create 'Hour' column for use in weather data merge
# 1. Separate hour from start time
crime_df[['hour_separated', 'time_separated']] = crime_df['Start Time'].str.split(':', n=1, expand=True)
crime_df.head()
# Out:
#   Start Date   Start Time offensegroup              OFFENSE hour_separated  \
# 0   3/7/2022   6:14:00 PM      violent              robbery              6
# 1  3/20/2022  10:27:00 PM     property  motor vehicle theft             10
# 2  3/26/2022   6:33:00 PM     property         theft f/auto              6
# 3   3/7/2022   9:31:00 PM      violent              robbery              9
# 4  3/26/2022   9:46:00 PM     property          theft/other              9
#
#   time_separated
# 0       14:00 PM
# 1       27:00 PM
# 2       33:00 PM
# 3       31:00 PM
# 4       46:00 PM

# %%
# To create 'Hour' column for use in weather data merge
# 2. Separate out AM/PM
crime_df[['time_separated', 'AM/PM']] = crime_df['time_separated'].str.split(' ', expand=True)
crime_df.head()
# Out:
#   Start Date   Start Time offensegroup              OFFENSE hour_separated  \
# 0   3/7/2022   6:14:00 PM      violent              robbery              6
# 1  3/20/2022  10:27:00 PM     property  motor vehicle theft             10
# 2  3/26/2022   6:33:00 PM     property         theft f/auto              6
# 3   3/7/2022   9:31:00 PM      violent              robbery              9
# 4  3/26/2022   9:46:00 PM     property          theft/other              9
#
#   time_separated AM/PM
# 0          14:00    PM
# 1          27:00    PM
# 2          33:00    PM
# 3          31:00    PM
# 4          46:00    PM

# %%
# Create 'Hour' column for use in weather data merge
crime_df['Hour'] = (crime_df['hour_separated'] + ":00" + crime_df['AM/PM'])

# Remove unnecessary columns and reorganize
crime_df = crime_df[['Start Date', 'Start Time', 'Hour', 'offensegroup', 'OFFENSE']]
crime_df.head()
# Out:
#   Start Date   Start Time     Hour offensegroup              OFFENSE
# 0   3/7/2022   6:14:00 PM   6:00PM      violent              robbery
# 1  3/20/2022  10:27:00 PM  10:00PM     property  motor vehicle theft
# 2  3/26/2022   6:33:00 PM   6:00PM     property         theft f/auto
# 3   3/7/2022   9:31:00 PM   9:00PM      violent              robbery
# 4  3/26/2022   9:46:00 PM   9:00PM     property          theft/other

# %%
# Add leading zero to month and day of date
crime_df[['month', 'day', 'year']] = crime_df['Start Date'].str.split("/", expand=True)
crime_df['month'] = crime_df['month'].str.zfill(width=2)
crime_df['day'] = crime_df['day'].str.zfill(width=2)
crime_df['Start Date'] = crime_df['month'] + "/" + crime_df['day'] + "/" + crime_df['year']

# Reorganize columns
crime_df = crime_df[['Start Date', 'Start Time', 'Hour', 'offensegroup', 'OFFENSE']]
crime_df.head()
# Out:
#    Start Date   Start Time     Hour offensegroup              OFFENSE
# 0  03/07/2022   6:14:00 PM   6:00PM      violent              robbery
# 1  03/20/2022  10:27:00 PM  10:00PM     property  motor vehicle theft
# 2  03/26/2022   6:33:00 PM   6:00PM     property         theft f/auto
# 3  03/07/2022   9:31:00 PM   9:00PM      violent              robbery
# 4  03/26/2022   9:46:00 PM   9:00PM     property          theft/other

# %%
# Save cleaned data to .csv
crime_df.to_csv("Resources/dc_crime.csv", index_label="ID")

# %%
# Open and preview dc_crime.csv file
new_file = "Resources/dc_crime.csv"
crime_df = pd.read_csv(new_file)
crime_df.head()
# Out:
#    ID  Start Date   Start Time     Hour offensegroup              OFFENSE
# 0   0  03/07/2022   6:14:00 PM   6:00PM      violent              robbery
# 1   1  03/20/2022  10:27:00 PM  10:00PM     property  motor vehicle theft
# 2   2  03/26/2022   6:33:00 PM   6:00PM     property         theft f/auto
# 3   3  03/07/2022   9:31:00 PM   9:00PM      violent              robbery
# 4   4  03/26/2022   9:46:00 PM   9:00PM     property          theft/other

# %% [markdown]
# ### Merge Weather Data and Crime Data

# %%
# Convert weather date to match crime date for merge
weather_df['Date'] = pd.to_datetime(weather_df['Date'], format='%Y-%m-%d').dt.strftime('%m/%d/%Y')
weather_df.head()
# Out:
#    ID        Date     Hour  Max Temp (f)  Min Temp (f)  Avg Temp (f)  \
# 0   0  02/19/2022  12:00AM          49.3          30.4          40.5
# 1   1  02/19/2022   1:00AM          49.3          30.4          40.5
# 2   2  02/19/2022   2:00AM          49.3          30.4          40.5
# 3   3  02/19/2022   3:00AM          49.3          30.4          40.5
# 4   4  02/19/2022   4:00AM          49.3          30.4          40.5
#
#    Total Precipitation (in) Day Condition  Hour Temp (f) Hour Condition  \
# 0                       0.0         Sunny           34.0          Clear
# 1                       0.0         Sunny           33.4          Clear
# 2                       0.0         Sunny           32.9          Clear
# 3                       0.0         Sunny           32.4          Clear
# 4                       0.0         Sunny           32.0          Clear
#
#    Hour Precipitation (in)
# 0                      0.0
# 1                      0.0
# 2                      0.0
# ...

# %%
# Merge crime data with weather data
crime_weather_df = pd.merge(crime_df, weather_df, how='left', left_on=['Start Date', 'Hour'], right_on=['Date', 'Hour'])
crime_weather_df.head()
# Out:
#    ID_x  YEAR Start Date   Start Time     Hour offensegroup  \
# 0     0  2022   3/7/2022   6:14:00 PM   6:00PM      violent
# 1     1  2022  3/20/2022  10:27:00 PM  10:00PM     property
# 2     2  2022  3/26/2022   6:33:00 PM   6:00PM     property
# 3     3  2022   3/7/2022   9:31:00 PM   9:00PM      violent
# 4     4  2022  3/26/2022   9:46:00 PM   9:00PM     property
#
#                OFFENSE  ID_y Date  Max Temp (f)  Min Temp (f)  Avg Temp (f)  \
# 0              robbery   NaN  NaN           NaN           NaN           NaN
# 1  motor vehicle theft   NaN  NaN           NaN           NaN           NaN
# 2         theft f/auto   NaN  NaN           NaN           NaN           NaN
# 3              robbery   NaN  NaN           NaN           NaN           NaN
# 4          theft/other   NaN  NaN           NaN           NaN           NaN
#
#    Total Precipitation (in) Day Condition  Hour Temp (f) Hour Condition  \
# ...
